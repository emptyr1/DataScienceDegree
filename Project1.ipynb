# %%
print 'Hi! Please find the answers/visualization to questions of project 1'
print 'Mudit Uppal'
# Out:
# Hi! Please find the answers/visualization to questions of project 1
# Mudit Uppal

# %%
from pandas import *
from ggplot import *

def plot_weather_data(turnstile_weather):
    '''

    Here are some suggestions for things to investigate and illustrate:
     * Ridership by time of day or day of week
     * How ridership varies based on Subway station
     * Which stations have more exits or entries at different times of day
     
    You can check out:
    https://www.dropbox.com/s/meyki2wl9xfa7yk/turnstile_data_master_with_weather.csv
    '''
    turnstile_weather = pandas.read_csv(turnstile_weather)
    turnstile_weather = turnstile_weather[['UNIT',"ENTRIESn_hourly"]].groupby('UNIT', as_index=False).mean()
    turnstile_weather=turnstile_weather.reset_index()
    
    sortedEntries = turnstile_weather.sort(["ENTRIESn_hourly", "UNIT"], ascending=False)
    sortedEntries=sortedEntries.head(14)
    sortedEntries=sortedEntries.reset_index()
    
    plot3 = ggplot(sortedEntries, aes(x='UNIT', y='ENTRIESn_hourly')) + \
        geom_bar(aes(weight='ENTRIESn_hourly'),fill='lightblue',stat = 'identity') + \
        ggtitle('How ridership varies by subway station') + xlab('Station') + ylab('Entries')
    
    print plot3
     

if __name__== '__main__':
    plot_weather_data('data/turnstile_data_master_with_weather.csv')
# Out:
# <ggplot: (282183641)>

# %%
from pandas import *
from ggplot import *

def plot_weather_data(turnstile_weather):
    '''

    Here are some suggestions for things to investigate and illustrate:
     * Ridership by time of day or day of week
     * How ridership varies based on Subway station
     * Which stations have more exits or entries at different times of day
     
    You can check out:
    https://www.dropbox.com/s/meyki2wl9xfa7yk/turnstile_data_master_with_weather.csv
    '''
    turnstile_weather = pandas.read_csv(turnstile_weather)
    turnstile_weather = turnstile_weather.reset_index()
    with_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==1]
    without_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==0]
    #print len(with_rain)
    #print with_rain
    
    
    turnstile_weather.DATEn = pandas.to_datetime(turnstile_weather.DATEn)
    f = lambda x:int(x[1:])
    turnstile_weather['station'] = turnstile_weather['UNIT'].map(f)
    
    station_part1 = turnstile_weather[turnstile_weather['station']>=10]
    station_part2 = station_part1[station_part1['station']<20]
    
    filteredCols = station_part2[['UNIT', 'station', 'DATEn', 'ENTRIESn_hourly']]
    #print filteredCols
    grouped = filteredCols.groupby(['UNIT','station', 'DATEn'], as_index=False).sum()
    #print grouped
    #print turnstile_weather.station.head(50)
    #testplot = ggplot(aes(x='ENTRIESn_hourly'), data = turnstile_weather) + geom_histogram()
    
    plot1 = ggplot(grouped, aes(x='DATEn', y='ENTRIESn_hourly', color='UNIT')) + \
            geom_line() + \
            ggtitle('How ridership varies by subway station')  + \
            xlab('Date') + ylab('Entries') + \
            theme(axis_text_x = element_text(angle = 45, hjust = 1))
            
        
    print plot1
    
if __name__== '__main__':
    plot_weather_data('data/turnstile_data_master_with_weather.csv')
    
''' 1) Regarding lambda, they are a way of creating anonymous functions that aren't necessarily bound to a name. 
The functions you create using lambda are meant to be simple, typically taking a few arguments at most and then returning 
the result of the expression on the right side of the colon. You won't be doing complex manipulations on a single line, 
but they come in handy for simple operations that may not warrant definition of a standalone function. There are a few links 
in @194 that might help your understanding of lambda functions.
 
2) The documentation of the .map function on pandas Series does have two arguments, but the second is optional, 
dealing with what to do with missing data. Only the first argument is required, and takes a function or other
correspondence for the individual values of the Series being operated on for mapping.
 
Taking these together, we can interpret the code written in words like so: For each row, 
take the value in the UNIT column (x) and retain the values from the second character onward (x[1:]). 
Cast that value as an integer (int) and store that mapped value in the station column. '''
# Out:
# <ggplot: (284662633)>
# ...

# %%
from pandas import *
from ggplot import *

def plot_weather_data(turnstile_weather):
    '''
    Here are some suggestions for things to investigate and illustrate:
     * Ridership by time of day or day of week
     * How ridership varies based on Subway station
     * Which stations have more exits or entries at different times of day
     
    You can check out:
    https://www.dropbox.com/s/meyki2wl9xfa7yk/turnstile_data_master_with_weather.csv
    '''
    turnstile_weather = pandas.read_csv(turnstile_weather)
    turnstile_weather = turnstile_weather.reset_index()
    
    with_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==1]
    without_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==0]
    plot(with_rain)
    #print len(with_rain)
    #print with_rain
    turnstile_weather.DATEn = pandas.to_datetime(turnstile_weather.DATEn)
    #####################################################################
    groupby_unit = turnstile_weather.groupby('rain',as_index = False).sum()
    groupby_unit = groupby_unit.sort('ENTRIESn_hourly',ascending=False).head(10)
    groupby_unit = groupby_unit.reset_index(drop=True)
    
    #groupedbyRain = turnstile_weather.groupby('rain').sum()
    print groupby_unit
    
if __name__== '__main__':
    plot_weather_data('data/turnstile_data_master_with_weather.csv')
# Out:
#    rain       index  Unnamed: 0    Hour  ENTRIESn_hourly  EXITSn_hourly  \
# 0     0  5251643679  5251643679  957746         95777720       77591707
# 1     1  3453823546  3453823546  480013         48754607       39434426
#
#      maxpressurei  maxdewpti  mindewpti    minpressurei  meandewpti  \
# 0  2639516.369999    4810450    3996230  2627966.280001     4388041
# 1  1323222.009999    2742597    2371595  1316407.290001     2566242
#
#    meanpressurei    fog  meanwindspdi  mintempi  meantempi  maxtempi  \
# 0     2634374.29   4348        479338   4942978    5707708   6419732
# 1     1319547.59  17701        252075   2468680    2772747   3050387
#
#     precipi  thunder
# 0      0.00        0
# 1  22732.03        0

# %%
import numpy as np
import scipy
import scipy.stats
import pandas

def manWhitneyTest(turnstile_weather):
    turnstile_weather = pandas.read_csv(turnstile_weather)
    with_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==1]
    with_rain_mean = np.mean(with_rain)
    
    without_rain = turnstile_weather['ENTRIESn_hourly'][turnstile_weather['rain']==0]
    without_rain_mean = np.mean(without_rain)
    
    U, p = scipy.stats.mannwhitneyu(with_rain, without_rain)
    print with_rain_mean, without_rain_mean, U, p
    
    t, prob = scipy.stats.ttest_ind(with_rain, without_rain)
    print t, prob
    
if __name__== '__main__':
    manWhitneyTest('data/turnstile_data_master_with_weather.csv')
# Out:
# 1105.44637675 1090.27878015 1924409167.0 0.0249999127935
# 1.11212011293 0.266088536255
