# %%
ls
# Out:
# Course_Introduction.ipynb*             Series_and_Dataframes.ipynb*
# Different_Data_Where_To_Find_It.ipynb* Slicing_and_Indexing.ipynb*
# Employment_Figures.csv*                Untitled0.ipynb
# Getting_Started_with_IPython.ipynb*    What_is_Data_Science.ipynb*
# IPython_Googlemaps.ipynb*              avg_weather.csv*
# Most_Common_Commands.ipynb*            blumenauer_data.csv*
# Plotly.ipynb*

# %%
import pandas as pd # the pandas package
from pandas import *
randn = np.random.randn
import numpy as np

# %%
houses = pd.read_csv('2009_manhattan.csv')
#houses.head()
prices = houses[['SALE PRICE', 'YEAR BUILT']]

sortedd = prices.sort(['SALE PRICE'])
sortedd

#houses.plot()
# Out:
#       SALE PRICE  YEAR BUILT
# 14005         $0        1986
# 1             $0        1900
# 6             $0        1900
# 23            $0        1900
# 33            $0        1900
# 50            $0        1900
# 52            $0        1925
# 59            $0           0
# 60            $0           0
# 61            $0           0
# 62            $0           0
# 63            $0           0
# 66            $0        1928
# 69            $0        2005
# 79            $0        1905
# 81            $0           0
# 82            $0           0
# 87            $0        1920
# 89            $0        1936
# 90            $0        1936
# 92            $0        2009
# 93            $0        2009
# 94            $0        1900
# 95            $0        1900
# 96            $0        1900
# 97            $0        1970
# 98            $0        1920
# 101           $0        1901
# 102           $0        1901
# 103           $0        1910
# ...          ...         ...
# ...
